# %%
from matplotlib import pyplot as plt
days  = [0,1,2,3,4,5,6]
money_spent = [10,12,12,10,14,22,24]
plt.plot(days, money_spent)

# %% [markdown]
# # The multiple line graph by calling the plt.plot() two times with same y paramm

# %%
time = [0, 1, 2, 3, 4]
revenue = [200, 400, 650, 800, 850]
costs = [150, 500, 550, 550, 560]

plt.plot(time , revenue)
plt.plot(time, costs)
plt.show()

# %%
time = [0, 1, 2, 3, 4]
revenue = [200, 400, 650, 800, 850]
costs = [150, 500, 550, 550, 560]

plt.plot(time, revenue, color='purple', linestyle   = "--")
plt.plot(time,costs, color = "#82edc9", marker = "s")
plt.show ()

# %%
x = range(12)
y = [3000, 3005, 3010, 2900, 2950, 3050, 3000, 3100, 2980, 2980, 2920, 3010]
plt.plot(x, y)

#your code here
plt.axis([0, 12, 2900, 3100])
plt.xlabel("Time")
plt.ylabel("Dollars spent on the coffee")
plt.title("Total amount spent on the coffee")
plt.show()

# %%
# In the above snippet we are setting the axis property
